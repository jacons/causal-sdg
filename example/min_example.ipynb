# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import networkx as nx
import numpy as np
import pandas as pd
from dowhy import gcm
from matplotlib import pyplot as plt

from causal_sdg import (make_dist_from_dataframe2, ConditionalMechanismFromDict,
                        Str2ListProcessing, FunctionApplying, CausalGenerator)

# %% [markdown]
# # 1 - Import the training data

# %%
cv_dt = pd.read_json('cvs.json',dtype={
    "gender": "str",
    "ethnic_group": "str",
    "religion": "str",
    "disability": "str",
    "sexual_orientation": "str",
    "perceived_foreign": "str",
    "job_cat": "str",
    "edu_eqf": "str",
    "years_exp": "str",
    "age": "str",
    "skills": "object",
    "prof_exp": "object",
})

# %%
cv_dt
# Out:
#       gender                              ethnic_group      religion  \
# 0        Man                                 No answer       Judaism
# 1        Man                           Within majority  Christianity
# 2     No-Man                           Within majority       Secular
# 3        Man                           Within majority  Christianity
# 4     No-Man  Belonging to both, minority and majority          None
# ...      ...                                       ...           ...
# 1995  No-Man                           Within majority          None
# 1996     Man                           Within majority  Christianity
# 1997  No-Man                     Belonging to minority  Christianity
# 1998  No-Man                           Within majority       Secular
# 1999     Man                                 No answer  Christianity
#
#      disability sexual_orientation perceived_foreign  \
# 0            No              LGBT+               Yes
# 1            No       Heterosexual               Yes
# 2            No       Heterosexual                No
# 3     No answer       Heterosexual                No
# 4     No answer       Heterosexual               Yes
# ...         ...                ...               ...
# 1995         No              LGBT+               Yes
# 1996         No       Heterosexual                No
# 1997         No       Heterosexual                No
# 1998  No answer       Heterosexual               Yes
# 1999         No              LGBT+               Yes
#
#                                                 job_cat          edu_eqf age  \
# 0                                Teaching professionals          level 6  26
# 1          Agricultural, forestry and fishery labourers          level 6  20
# 2              Legal, social and cultural professionals  level 5 or less  32
# 3          Agricultural, forestry and fishery labourers          level 6  36
# 4                        Other clerical support workers          level 6  35
# ...                                                 ...              ...  ..
# 1995          Business and administration professionals          level 6  52
# 1996                     Other clerical support workers  level 5 or less  34
# 1997                             Teaching professionals          level 6  28
# 1998  Information and communications technology prof...  level 5 or less  44
# 1999            Numerical and material recording clerks          level 6  31
#
#      years_exp                                             skills  \
# 0            1          [Swedish, Italian, public administration]
# 1            4  [office software, hydraulics, manage teamwork,...
# 2           14  [teach teaching principles, perform mathematic...
# 3           14  [analyse the context of an organisation, adapt...
# 4            8      [leading and motivating, sales argumentation]
# ...        ...                                                ...
# 1995         8  [office software, hardware architectures, set ...
# 1996        10  [customer service, organise event participants...
# 1997         5  [swim, Spanish, English, planning and organisi...
# 1998        23  [customer service, manage teamwork, cloud tech...
# 1999        11  [mergers and acquisitions, building and develo...
#
#                                       prof_exp
# 0                                           []
# 1                                           []
# 2              [university teaching assistant]
# 3                         [dry press operator]
# 4                                           []
# ...                                        ...
# 1995                                        []
# 1996  [Administrative and commercial managers]
# 1997                [digital literacy teacher]
# 1998                                        []
# 1999             [Food preparation assistants]
#
# [2000 rows x 12 columns]

# %% [markdown]
# # 2 - Define graphically the causal relations among the features
# We define the causal graph as a directed graph (DiGraph) using the NetworkX library. The nodes represent the features, and the edges represent the causal relationships between them. The color of the nodes is used to distinguish between different types of features.

# %%
cf = nx.DiGraph()
cf.add_nodes_from(list(cv_dt.columns))
cf.add_edges_from([("age", "years_exp"), ("job_cat", "prof_exp"),
                   ("edu_eqf", "skills"), ("years_exp", "skills"),
                   ("job_cat", "skills")]),

node_colors = []
for node in cf.nodes():
    if node == "job_cat":
        node_colors.append("red")
    else:
        node_colors.append("#99FFFF")

pos = nx.spring_layout(cf, seed=17)
nx.draw(cf, pos,
        with_labels=True,
        node_color=node_colors,
        font_size=10,
        arrowstyle='->',
        arrowsize=20)

plt.title("Curriculum' causal graph", fontsize=15, fontweight="bold")
plt.show()

# %% [markdown]
# # 3 - Define the CPT (Conditional Probability Table) for used for the assignment "occupation -> skills"
# We have to do this manually, since "skills" is a "set"-random variable and the DoWhy package does not support it. So we build a custom mechanism that from D_{Skills|Category,Education, Experience}, samples multiple skills following the conditional distribution.

# %%
cpt_skills = make_dist_from_dataframe2(data=cv_dt,
                                       X=["job_cat", "edu_eqf", "years_exp"],
                                       Y="skills",
                                       marginal_on="job_cat")

print(cpt_skills.check_distribution_validity(verbose=True))

cpt_prof_exp = make_dist_from_dataframe2(data=cv_dt,
                                         X="job_cat",
                                         Y="prof_exp")

print(cpt_prof_exp.check_distribution_validity(verbose=True))
# Out:
# Zero distribution : 0 on 827
# Only one element distribution 12 on 827
# True
# Zero distribution : 0 on 20
# Only one element distribution 1 on 20
# True

# %% [markdown]
# # 4 — Define the Structural Equations Model (SEM)
# We define the SEM as a list of tuples, where each tuple contains the name of the node and the mechanism used to sample it. The mechanism can be either a classifier or an empirical distribution.

# %%
structural_equation_model = {

    # They are root nodes, so we use the empirical distribution
    "gender": gcm.EmpiricalDistribution(),
    "disability": gcm.EmpiricalDistribution(),
    "age": gcm.EmpiricalDistribution(),
    "job_cat": gcm.EmpiricalDistribution(),
    "ethnic_group": gcm.EmpiricalDistribution(),
    "religion": gcm.EmpiricalDistribution(),
    "sexual_orientation": gcm.EmpiricalDistribution(),
    "perceived_foreign": gcm.EmpiricalDistribution(),
    "edu_eqf": gcm.EmpiricalDistribution(),

    "years_exp": gcm.ClassifierFCM(),

    # We use a custom mechanism to sample the skills since is a set-random variable
    "skills": ConditionalMechanismFromDict(cpt_data=cpt_skills, num_func=lambda x: np.random.randint(2, 8),
                                           return_always_list=True),
    "prof_exp": ConditionalMechanismFromDict(cpt_data=cpt_prof_exp, num_func=lambda x: np.random.randint(0, 2),
                                             return_always_list=True),

}

pre_processing = FunctionApplying()

# We define a set of post-processing functions to apply on the generated data
post_processing = FunctionApplying({

    # The skill node returns a str-version of a list of skills, so we need to convert the string into a list
    "skill_list": Str2ListProcessing(feature_name="ast_skills", apply_on=["skills"], replace=True),
    "prof_list": Str2ListProcessing(feature_name="ast_prof_exp", apply_on=["prof_exp"], replace=True),
})

# %% [markdown]
# # 5 - Fitting the SDG (Synthetic Data Generator)
# We fit the SDG using the original dataset and the defined SEM. The fitting process involves learning the parameters of the causal mechanisms from the data. We also apply pre-processing and post-processing functions to transform the data before and after fitting.

# %%
# We create the SDG object, passing the causal graph, pre-processing and post-processing functions
sdg = CausalGenerator(direct_graph=cf,
                      post_processing=post_processing,
                      pre_processing=pre_processing)
# We fit the SDG using the original dataset and the defined SEM
_, evaluation = sdg.custom_fit(dataset=cv_dt,
                               causal_mechanisms=structural_equation_model)
# Out:
# Fitting causal mechanism of node prof_exp: 100%|██████████| 12/12 [00:08<00:00,  1.34it/s]

# %% [markdown]
# # 6 - Generate synthetic data
# In this section, we generate synthetic data using the fitted SDG. We can specify the number of elements to generate and whether to apply any interventions on the generated data.

# %% [markdown]
# ## 6.1 - Simple sampling
# We can generate synthetic data by simply calling the sample method of the SDG object

# %%
sdg.sample(elements=10)
# Out:
#    gender           ethnic_group      religion disability sexual_orientation  \
# 0  No-Man        Within majority       Secular         No       Heterosexual
# 1  No-Man        Within majority       Islamic         No              LGBT+
# 2     Man  Belonging to minority  Christianity  No answer              LGBT+
# 3     Man        Within majority          None  No answer       Heterosexual
# 4  No-Man        Within majority          None         No       Heterosexual
# 5  No-Man        Within majority          None         No              LGBT+
# 6     Man        Within majority         Other         No              LGBT+
# 7     Man        Within majority          None         No       Heterosexual
# 8     Man  Belonging to minority          None         No       Heterosexual
# 9  No-Man        Within majority     No answer         No       Heterosexual
#
#   perceived_foreign                                            job_cat  \
# 0                No  Information and communications technology prof...
# 1                No           Legal, social and cultural professionals
# 2               Yes  Information and communications technology prof...
# 3               Yes    Science and engineering associate professionals
# 4                No          Business and administration professionals
# 5               Yes                     Other clerical support workers
# 6                No                           Personal service workers
# 7                No           Legal, social and cultural professionals
# 8                No    Science and engineering associate professionals
# 9               Yes  Information and communications technology prof...
#
#            edu_eqf        age years_exp  \
# 0  level 5 or less         47        28
# 1          level 6         27         0
# 2          level 7         45        30
# 3          level 6         35        12
# 4          level 6         61        23
# 5  level 5 or less         29         9
# 6  level 5 or less         20         3
# 7          level 6         36         8
# 8          level 6         25         1
# 9          level 7  No answer         4
#
#                                               skills  \
# 0                          [French, manage teamwork]
# 1  [adapt to change, knowledge base, determine fi...
# 2  [office software, electronics and automation, ...
# 3  [project management, computer programming, adv...
# 4  [project management, business ICT systems, mer...
# 5                [use ICT ticketing system, English]
# 6  [show professional responsibility, working eff...
# 7  [English, planning and organising, social netw...
# 8  [consult with business clients, computer graph...
# 9  [collaborate in company's daily operations, CS...
#
#                         prof_exp
# 0  [irrigation system installer]
# 1        [statistical assistant]
# 2              [waiter/waitress]
# 3                             []
# 4                             []
# 5                             []
# 6                [forest worker]
# 7                             []
# 8                             []
# 9          [editorial assistant]

# %% [markdown]
# ## 6.2 - Sampling with interventions
# We can also generate synthetic data with interventions by specifying the values of the features we want to intervene on. For example, we can set the gender (or age) to a fixed value (hard intervention)

# %%
sdg.sample(interventions={"gender": lambda x: "Man", "age": lambda x: "36"},
           elements=10)
# Out:
#   gender     ethnic_group      religion disability sexual_orientation  \
# 0    Man        No answer       Islamic         No              LGBT+
# 1    Man        No answer          None         No       Heterosexual
# 2    Man  Within majority          None  No answer       Heterosexual
# 3    Man  Within majority          None         No              LGBT+
# 4    Man  Within majority     No answer         No       Heterosexual
# 5    Man  Within majority       Judaism         No       Heterosexual
# 6    Man  Within majority  Christianity         No       Heterosexual
# 7    Man  Within majority     No answer         No       Heterosexual
# 8    Man  Within majority     No answer        Yes              LGBT+
# 9    Man  Within majority       Secular        Yes       Heterosexual
#
#   perceived_foreign                                            job_cat  \
# 0                No    Science and engineering associate professionals
# 1                No                             Teaching professionals
# 2                No                   Craft and related trades workers
# 3                No       Production and specialised services managers
# 4               Yes                 Commissioned armed forces officers
# 5                No  Chief executives, senior officials and legisla...
# 6                No           Legal, social and cultural professionals
# 7               Yes              Science and engineering professionals
# 8                No                             Teaching professionals
# 9                No          Business and administration professionals
#
#            edu_eqf age years_exp  \
# 0  level 5 or less  36        11
# 1          level 6  36        25
# 2  level 5 or less  36        16
# 3  level 5 or less  36        11
# 4  level 5 or less  36         1
# 5          level 6  36        18
# 6  level 5 or less  36        14
# 7  level 5 or less  36        29
# 8          level 6  36        29
# 9  level 5 or less  36         5
#
#                                               skills  \
# 0  [principles of combustion engines, operating s...
# 1  [electronics and automation, Italian, develop ...
# 2  [computer graphics, English, work in a hospita...
# 3  [International Maritime Organisation conventio...
# 4                        [assist customers, Spanish]
# 5  [computer programming, plan social media marke...
# 6  [investigation research methods, English, comp...
# 7  [conduct scholarly research, be friendly to pa...
# 8  [manage different departments in a hospitality...
# 9  [develop digital content, geometry, computer p...
#
#                              prof_exp
# 0                [membership manager]
# 1  [science teacher secondary school]
# 2                                  []
# 3                                  []
# 4                                  []
# 5                                  []
# 6                                  []
# 7                   [nurse assistant]
# 8           [sales support assistant]
# 9                         [secretary]

# %%
sdt = sdg.sample_and_save(
    folder=".",
    name=f"synthetic_example.json",
    elements=2000,
    verbose=False,
    fill_missing="uniform",
    apply_post_processing=True,
    add_file_info=True
)
# Out:
# Warning: Column 'skills' contains non-hashable types and will be skipped for unique value counting.
# Warning: Column 'prof_exp' contains non-hashable types and will be skipped for unique value counting.
